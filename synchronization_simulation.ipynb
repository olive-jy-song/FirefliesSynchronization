# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
Kr = 0.4
pi = np.pi 
w = 50
dt = 0.01

step_size = 200
flies_index = [i for i in range(N)]
flies_ini_phase = np.random.uniform(-pi,pi,N) 
curr_phase = flies_ini_phase 
phases_minus_mean = []

# %%
def calculate_phases(curr_phase, step_size, dt): 
    for t in range (0,step_size):    
        phase_mean = np.mean(curr_phase)  
        for i in range (0,N): 
            curr_phase[i] += w + dt * Kr * np.sin(phase_mean-curr_phase[i])
    phases_minus_mean = curr_phase - np.mean(curr_phase) 
    return phases_minus_mean 

def plot_phases(curr_phase): 
    plt.scatter(flies_index, curr_phase) 
    plt.xlabel('Index of Fireflies')
    plt.ylabel('Phases Compared to Mean')

# %%
plot_phases(curr_phase)
plt.title('Randomly Initialized Fireflies Phases')
print("The average phase is ", np.mean(curr_phase)) 
print("The standard deviation of phase is ", np.std(curr_phase))
# Out:
# The average phase is  -0.08751118374919437
# The standard deviation of phase is  1.9135300591432347

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 200 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 200 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 400 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 400 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 600 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 600 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 800 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 800 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 1000 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 1000 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 1200 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 1200 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 1400 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 1400 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 1600 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 1600 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 1800 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 1800 Steps')

# %%
phases_minus_mean = calculate_phases(curr_phase, step_size, dt) 
plot_phases(phases_minus_mean) 
plt.title('Fireflies Phases After 2000 Steps')
# Out:
# Text(0.5, 1.0, 'Fireflies Phases After 2000 Steps')
